# %%
# !!pip install youtube_transcript_api
# Out:
# ['Collecting youtube_transcript_api',
#  '  Downloading youtube_transcript_api-0.6.2-py3-none-any.whl (24 kB)',
#  'Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube_transcript_api) (2.31.0)',
#  'Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube_transcript_api) (3.3.2)',
#  'Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->youtube_transcript_api) (3.6)',
#  'Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube_transcript_api) (2.0.7)',
#  'Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->youtube_transcript_api) (2024.2.2)',
#  'Installing collected packages: youtube_transcript_api',
#  'Successfully installed youtube_transcript_api-0.6.2']

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import spacy

# %%
#https://www.alura.com.br/artigos/lemmatization-vs-stemming-quando-usar-cada-uma

# %%
# !python -m spacy download pt
# Out:
# ⚠ As of spaCy v3.0, shortcuts like 'pt' are deprecated. Please use the
# full pipeline package name 'pt_core_news_sm' instead.
# Collecting pt-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.7.0/pt_core_news_sm-3.7.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-sm==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.1.5)
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %%
nlp = spacy.load('pt_core_news_sm')

# %%
# !pip install leia-br
# Out:
# Collecting leia-br
#   Downloading leia_br-0.0.1-py2.py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.0/130.0 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from leia-br) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->leia-br) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->leia-br) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->leia-br) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->leia-br) (2024.2.2)
# Installing collected packages: leia-br
# Successfully installed leia-br-0.0.1

# %%
# !pip install Unidecode
# Out:
# Collecting Unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: Unidecode
# Successfully installed Unidecode-1.3.8

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from youtube_transcript_api import YouTubeTranscriptApi
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.stem import *
from nltk.stem.porter import *
from nltk import tokenize
from LeIA import SentimentIntensityAnalyzer as si
import string
from unidecode import unidecode

# %%
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
'''url = 'https://raw.githubusercontent.com/Dsaqui/Sentiment_Analisys_dataset/main/Dataset.csv'
dataset = pd.read_csv(url)
youtubelink='https://www.youtube.com/watch?v='
dataset['Link'] = dataset['Link'].fillna(youtubelink+dataset['ID'])
dataset'''
# Out:
# "url = 'https://raw.githubusercontent.com/Dsaqui/Sentiment_Analisys_dataset/main/Dataset.csv'\ndataset = pd.read_csv(url)\nyoutubelink='https://www.youtube.com/watch?v='\ndataset['Link'] = dataset['Link'].fillna(youtubelink+dataset['ID'])\ndataset"

# %%
dataset=pd.read_csv('dados-pt-videos_so_id_27_28.csv', engine='c', sep=',')

# %%
dataset
# Out:
#               ID
# 0    8irga_AqRdw
# 1    mijGutvsa_U
# 2    C546BsuxHxo
# 3    NHFt7QTyUfs
# 4    ITjV9Oc5ZZM
# ..           ...
# 930  lXXNNcHeboE
# 931  WJbKyP3VbZw
# 932  CVBXzVtZaVA
# 933  Gj_PoIhRteg
# 934  XIbvY_or6GE
#
# [935 rows x 1 columns]

# %%
dataset.rename(columns={"video_id": "ID"}, inplace=True)
videoid = dataset["ID"]
videoid
# Out:
# 0      8irga_AqRdw
# 1      mijGutvsa_U
# 2      C546BsuxHxo
# 3      NHFt7QTyUfs
# 4      ITjV9Oc5ZZM
#           ...
# 930    lXXNNcHeboE
# 931    WJbKyP3VbZw
# 932    CVBXzVtZaVA
# 933    Gj_PoIhRteg
# 934    XIbvY_or6GE
# Name: ID, Length: 935, dtype: object

# %%
vetorizar = CountVectorizer(lowercase=False, max_features=300)
token_space = tokenize.WordPunctTokenizer()
non_words = nltk.corpus.stopwords.words("english")
non_words=['[music]', '[Music]', 'a', 'à', 'ao', 'aos', 'aquela', 'aquelas', 'aquele', 'aqueles', 'aquilo', 'as', 'às', 'até', 'com', 'como',
 'da', 'das', 'de', 'dela', 'delas', 'dele', 'deles', 'depois', 'do', 'dos', 'e', 'é', 'ela', 'elas', 'ele', 'eles', 'em', 'entre', 'era', 'eram',
 'éramos', 'essa', 'essas', 'esse', 'esses', 'esta', 'está', 'estamos', 'estão', 'estar', 'estas', 'estava', 'estavam', 'estávamos', 'este', 'esteja',
 'estejam', 'estejamos', 'estes', 'esteve', 'estive', 'estivemos', 'estiver', 'estivera', 'estiveram', 'estivéramos', 'estiverem', 'estivermos', 'estivesse',
 'estivessem', 'estivéssemos', 'estou', 'eu', 'foi', 'fomos', 'for', 'fora', 'foram', 'fôramos', 'forem', 'formos', 'fosse', 'fossem', 'fôssemos',
 'fui', 'há', 'haja', 'hajam', 'hajamos', 'hão', 'havemos', 'haver', 'hei', 'houve', 'houvemos', 'houver', 'houvera', 'houverá', 'houveram', 'houvéramos',
 'houverão', 'houverei', 'houverem', 'houveremos', 'houveria', 'houveriam', 'houveríamos', 'houvermos', 'houvesse', 'houvessem', 'houvéssemos', 'isso',
 'isto', 'já', 'lhe', 'lhes', 'mais', 'mas', 'me', 'mesmo', 'meu', 'meus', 'minha', 'minhas', 'muito', 'na', 'nas', 'no', 'nos', 'nós', 'nossa', 'nossas',
 'nosso', 'nossos', 'num', 'numa', 'o', 'os', 'ou', 'para', 'pela', 'pelas', 'pelo', 'pelos', 'por', 'qual', 'quando', 'que', 'quem', 'são', 'se', 'seja',
 'sejam', 'sejamos', 'sem', 'ser', 'será', 'serão', 'serei', 'seremos', 'seria', 'seriam', 'seríamos', 'seu', 'seus', 'só', 'somos', 'sou', 'sua',
 'suas', 'também', 'te', 'tem', 'tém', 'temos', 'tenha', 'tenham', 'tenhamos', 'tenho', 'terá', 'terão', 'terei', 'teremos', 'teria', 'teriam', 'teríamos',
 'teu', 'teus', 'teve', 'tinha', 'tinham', 'tínhamos', 'tive', 'tivemos', 'tiver', 'tivera', 'tiveram', 'tivéramos', 'tiverem', 'tivermos', 'tivesse', 'tivessem',
 'tivéssemos', 'tu', 'tua', 'tuas', 'um', 'uma', 'você', 'vocês', 'vos']

 #'não', 'nem',

# %%
size = len(videoid)
data_transposed = dataset.T
deleted_video_number = 0
deleted_videos=[]
df_deleted_videos = pd.DataFrame()

for i in range(size):
  try:
    video = videoid.iloc[i]
    link_tans = YouTubeTranscriptApi.get_transcript(video, languages=['pt-BR', 'pt'])
    name = video +'.csv'
    name_txt = video +'.txt'
    new=[]
    with open('/content/'+ name_txt, 'w') as f:
      for k in link_tans:
        new.append(unidecode(k['text']).lower())
        f.write('%s\n' % k['text'])
    newx = [word for line in new for word in line.split()]
    bag_of_words =vetorizar.fit_transform(newx)
    newdf = pd.DataFrame(new, columns = ["text"])
    newdf.to_csv(name, index = False)
  except:
    deleted_videos.append(video)
    df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
    df_deleted_videos.to_csv('deleted_videos_BR.csv', sep=',')
    deleted_video_number+=1
    #dataset.pop(i)
    data_transposed.pop(i)
    i+=1
# Out:
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# ...
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)
# <ipython-input-16-f82ed23e21a5>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_deleted_videos = df_deleted_videos.append({'ID': video}, ignore_index=True)

# %%
from google.colab import files

# Fazer o download do arquivo
files.download('deleted_videos_BR.csv')

# %%
deleted_videos
# Out:
# ['C546BsuxHxo',
#  'JKuUZo9O5mU',
#  'j6XTck-nefI',
#  'DKpkx-eiBaY',
#  'WuLqoalQKPo',
#  'M5H6wmPMND4',
#  'RsWxe3K5eAk',
#  'vq4CGO8DlsM',
#  'jTMJK7wb0rM',
#  'AOlQleuNO7w',
#  'Gd6yNcKh-W4',
#  'vTYJS0-UPrU',
#  'Q-JBQGe5Zhw',
#  'DxYnnceBNXU',
#  'xuI6ecQIlwk',
#  'ofGsE31nRAk',
#  'ST_DOXsWN7U',
#  'uuT_fzBsGx0',
#  'hE7uNOnK71k',
#  'Q0lBZ3vcUW4',
#  'FQiBWdVlL8U',
#  'uNBEt8B_yVU',
#  'RW1UbvaJkRQ',
#  '6Ic2_XXJRSs',
#  'gMPdI2eXVLk',
#  '7ln1uKa-j6s',
#  'b13xnFp_LJs',
#  'tTrFPSSbEoU',
#  'fSW3f2t6eek',
#  't3btBudoWG8',
#  'fFx8Ia9lbJs',
#  'YPtjVYwJmq8',
#  'QtlBpXiDAUo',
#  'bziBNz1n-UI',
#  'Rc1axjOplWo',
#  'gxrX371IncY',
#  '5MHa6ciL4do',
#  'P07NgFqc0OY',
#  '72KnkOzja0s',
#  'LQEL5ltZFcg',
#  'Mo37-W75els',
#  'JrF7MyyyrA0',
#  'KR0g-1hnQPA',
#  'cnXapYkboRQ',
#  'smkSYfFnK00',
#  'A6K2dqCoin8',
#  'qvjnAMGclZA',
#  'al4yNkqadjw',
#  '-zSIhzZ8Two',
#  '_5TVA1u1q-4',
#  '3ISR-KIrsBk',
#  'pn9pJ18w-fA',
#  'NpDJpIOI-vo',
#  'bnChQbxLkkI',
#  'qPonh0v24ZE',
#  'OlFUZniChGw',
#  'zrmVURKvRcE',
#  'WQuNlg9bWyQ',
#  '2SXeL7jX6Sw',
#  '58psylsYafw',
#  'io05IqT6Auw',
#  '7KYzMBFZYno',
#  'IGK06LWNlyc',
#  'uxK6OIzw9kc',
#  'oa-TtrgY2eo',
#  'XOpTRTT3w7s',
#  'kIxEyPuFPH8',
#  'FXI_-OesT3A',
#  'ap-BkkrRg-o',
#  'AqQ2S_dbmuQ',
#  'z6bgpMLnooE',
#  'F1FSmHBSl7g',
#  'QGopWyf22Lc',
#  'fn3KWM1kuAw',
#  'QvKNhEb59mo',
#  'v5fMAWaPDGI',
#  'Igb0s_JV7iE',
#  '8ATSmY02ro4',
#  '7DWzipP3kRU',
#  'RLN8_TPWIhs',
#  'PSMeLVvim-w',
#  'LtjBFzTEO_k',
#  'CNLtpOeOPro',
#  'K0WTgthn82E',
#  '4zRVW_Z9Leo',
#  'yKI8CKJbpYs',
#  'RDKNpZSqcBM',
#  'FmQaEMow0Fw',
#  'WYJEh411Av4',
#  'N1Wy1swXJaQ',
#  '8S5s3GjwOZI',
#  '80uG581Ermk',
#  '_zZ7fIkpBgs',
#  'UCT1u3llHz0',
#  'ZyMNSmvkH1Y',
#  'ZHXnAfKq_EY',
#  'TnDJ0rxtk-w',
#  'UQQn7S_XmvA',
#  'gm0b_ijaYMQ',
#  'svzfYXrMA8o',
#  '0qR276a47QU',
#  '4czjS9h4Fpg',
#  'wE-aQO9XD1g',
#  'gYQwuYZbA6o',
#  'vKjj77YG4do',
#  'ODY6JWzS8WU',
#  'wj3q4EhfJ74',
#  '3oUNwBI5aWE',
#  'gjCSJIAKEPM',
#  'HakX_R0tK7Q',
#  'n4zgV2oHL0E',
#  'JdBYVNuky1M',
#  '5Pw7BBTwv3Y',
#  'z9eoubnO-pE',
#  'Ao6vQ7rxf8s',
#  'GuLYiV0Cjd4',
#  'DbICwMu4O8Y',
#  '3Q_1e6JiRsk',
#  'axR8KAzARaQ',
#  '4FenHltxMtw',
#  's5jyZwXuhzA',
#  'IazEN13o304',
#  'Uh9643c2P6k',
#  'Su-SlYfk7Es',
#  'dA9bubhZ_1Q',
#  'EPuU4V6CaQc',
#  'xOEK1zizQkA',
#  'jy0sGTbP3Qs',
#  'tMHhXzpwupU',
#  'rrKRle62Ys4',
#  '_y9vYoBfVAY',
#  'jopwfhsdTuc',
#  'hsLP5SLsUY0',
#  'EAlvoQX9ob4',
#  '08HJNlj-ZNs',
#  '5WtdCNDqfcM',
#  'NJnjt9RX2Bw',
#  'XYb9EElSf1g',
#  'XKfgdkcIUxw',
#  'm43rh-pI0P0',
#  '06HlsATe3rE',
#  'oPCm0swx7iY',
#  'qq-hLjb3UIc',
#  '2zCxvS9HWKI',
#  'exM1uajp--A',
#  'tkTTqI3DXUM',
#  '5IqBBYMv1Eg',
#  'uiz1e_DI8os',
#  'RGuJdnifQ0U',
#  'XoOF2EXZDYc',
#  '9euUSG1dyRU',
#  'GINqXigR-a8',
#  '8SMVKKegxdg',
#  'reEo7B910Ag',
#  'mdUbiR7elSE',
#  'hbKW7mTA_EY',
#  'uD-S__2zi70',
#  '76f6oRmBhMw',
#  'T79_Lse5R0k',
#  'C9XroHB8c5c',
#  'CUwg_JoNHpo',
#  'Ls3JJ5vzsYw',
#  '-J_77fQLUgs',
#  'quMMhGBpMrA',
#  'ZWopmb4du0I',
#  'KVaGM3BNAl4',
#  'nmMRMIE3MGw',
#  'y4hvDuRjGjw',
#  'tg_9v_9u9yk',
#  '6PaKy4Qd5t4',
#  '7q79UGOmklw',
#  '6je-Dn5FJmc',
#  'LWEXWwzRKCc',
#  'Vz4Sb1bl1IE',
#  'PLe_uYi39FY',
#  'ux6zXguiqxM',
#  'WiAzN_F4TOI',
#  'thSPGPnuuNg',
#  '4RA8Tfa6Sck',
#  'kJYRApNJij8',
#  'iGKYFNfSnH4',
#  'ccyMa4qxwNg',
#  'ubtEoq5gW7U',
#  'ZBXTHY8wEE8',
#  'GnoTgMEckDs',
#  'B99PMvsmyZ8',
#  'PZPuRrQQGTw',
#  'arapddN0bfc',
#  'lxktUzC6VOU',
#  'JwNmNoWrz70',
#  '-nV1whbprNU',
#  'Gs7GiPMu7Pc',
#  'TX9qSaGXFyg',
#  'GYkq9Rgoj8E',
#  'GLcjJ_G4vyU',
#  'fzcuWxAKuYc',
#  '6WIqRN-ynew',
#  'WTL1Vx0JWkk',
#  'wVc09e1Y2Xc',
#  'UfsaNGxt98A',
#  'RK2BOYlIEQI',
#  '_S_lWH6zK3k',
#  '3LxhLgRhHKA',
#  'mTL_cEKlO_I',
#  'aBPU4f6rH-w',
#  '36o2uMBduqA',
#  'LMmVjzApFqQ',
#  'cs1wKmQjFPg',
#  'W--S5txL38Q',
#  'KU6rk7tZ4ks',
#  'zUeHkP67P2I',
#  'mFE3hXI_D4A',
#  'fJp5i_MW6LM',
#  'LYN1B-oupxw',
#  'XLyuoTLhAqk',
#  'OHp-FrW4D6Y',
#  'JiSMF_cje08',
#  'S_RdjVvy-WY',
#  'DLA_64yz8Ss',
#  'gmh1fPn_fbA',
#  'zfn4QnYfuQs',
#  'ZwqakIjhQJI',
#  'rTcS0raY4F0',
#  'UL_o7IyvkcE',
#  '0Uzn1SHzBJk',
#  'UawWtYEdABA',
#  'X-ze_ZLTKuY',
#  'VguwJ_h2JIc',
#  'quvJB5rzv3I',
#  'PrH4rdV9d4M',
#  'ZB1GzEoIymw',
#  'baQvcgS96aQ',
#  'ZiP1l7jlIIA',
#  'jYbdPY6ZK0M',
#  '8VGbWZUHw8c',
#  'oHQ7RxC-_5E',
#  'KDwnyem8tk4',
#  'Y5AArQE8TrA',
#  'enR58PYHaWw',
#  'ENVo57nQ4aQ',
#  'Ii1iEBwMnJI',
#  'cBGeOj6kk_0',
#  'PtaoqMGzvXc',
#  'Oz6l9NO1jDc',
#  'uiCKGmkXqpo',
#  'dcPXMm8Hqm8',
#  'm5QJEZ0HfN4',
#  'RAhDUkyj-l0',
#  'gBxdxCHl06A',
#  '7xl2YsF9YXU',
#  'jlHdmKi4WPU',
#  'mE3u9rOU9hc',
#  'tGaA7ExyAeg',
#  'csfUE4r-NEs',
#  'eTR6L-wboYM',
#  'VcTv_GXPs4I',
#  'HXhsl-o35dg',
#  'BQ71WjwqQu8',
#  'vaZ_b25d9pY',
#  '9Ua13gSQIVQ',
#  '5W9WZm-ntxg',
#  'PoUMZ3OsC4E',
#  '9Pfsv0HmZCA',
#  'RtJt-jPo_oc',
#  '3NblY0mxii0',
#  's302xrhZeTo',
#  'QsgZ-rk39ao',
#  'fcSYYcYW1cY',
#  '_TBmvegNu-I',
#  '1rkemm27LW0',
#  'R2ChhzJ8QgE',
#  'FU2wRKDGqE0',
#  'DVuqX67dQI0',
#  'wfwfNYstwWo',
#  'v58gkYSVZR8',
#  'IhB7Jf9BeLo',
#  'DqMLozGrV8k',
#  'rFO50UO6ZlY',
#  'W0ss5iTjZX0',
#  'ntILRcXvyjI',
#  'XJhGJK-WHuU',
#  'WETuCQfsJVg',
#  'Zk0qhJfiwkc',
#  'ojDD4WzzksA',
#  'Ad58gFo7qpg',
#  'aypn3XjQrNU',
#  'OwaEsagax50',
#  'HbN2LJTp3-A',
#  'xkzTLX2i_5I',
#  'Lsqu8N4elwc',
#  'YiCIp9MUWpc',
#  '5-D1faIcUE4',
#  'utdEyB0sfB4',
#  'ctkW3V0Mh-k',
#  'g_SrsD8s8SM',
#  'tPr70yBa7To',
#  'ZUlGm_oPPLg',
#  'nvuYYk05NjM',
#  '0pg_Y41waaE',
#  'iuHXkbgtAq4',
#  'fhsn6yC_Rbw',
#  'HkS3RuU45Wk',
#  'flM1egug_2w',
#  'erdPvR2xzHo',
#  '5idBnwGeQEU',
#  'eBfiJ9PpU5o',
#  '1D63DHUylAw',
#  'JdFRjsEZrmU',
#  'DMjEvhgH1Bo',
#  'CzG5zaobF30',
#  'B1Iq3GYWLIw',
#  '7__r4FVj-EI',
#  'vVjR7QJc5bE',
#  'qY0nWLXu4jo',
#  'zmCJkc-PsUU',
#  'cdjTuWGh07E',
#  'kzdneBBSJpw',
#  'XxOh12Uhg08',
#  'VUREQfT-_iQ',
#  'IoZBQY0AmbQ',
#  'Myf2fQ0o3pc',
#  'x5PKTPiQslw',
#  'MIu4ASj1ZIw',
#  'kTW9GmupMFI',
#  'lyrBIWXOS64',
#  'lXKSv2dIY3g',
#  'lXXNNcHeboE',
#  'WJbKyP3VbZw',
#  'CVBXzVtZaVA',
#  'Gj_PoIhRteg',
#  'XIbvY_or6GE']

# %%
data_transposed.rename(index={"video_id": "ID"}, inplace=True)

data_transposed
# Out:
#             0            1            3            4            6    \
# ID  8irga_AqRdw  mijGutvsa_U  NHFt7QTyUfs  ITjV9Oc5ZZM  j03_Z28LL0w
#
#             7            8            9            10           11   ...  \
# ID  8JA7eoFaIWA  z-h4IU2HAzE  M91gKrhW8tY  E-UpzmoO0Ok  9gpcP5zod0A  ...
#
#             788          789          790          791          793  \
# ID  OIHSBuM4G5E  tgdErmnUlkM  Uc-Fh9Hrrq0  XhOAZb9T73c  vQACEDu2ulU
#
#             794          795          796          797          800
# ID  7Xaau4l9xH0  JdqxRvZTEfM  77A1ye1HxqY  ZOm7vJVpKKU  v8TpYzl3MIw
#
# [1 rows x 604 columns]

# %%
deleted_video_number
# Out:
# 331

# %%
df_new = data_transposed.T
new_videoid = df_new.loc[:,"ID"]

# %%
stemmer = PorterStemmer()

# %%
new_size = len(new_videoid)
new_size
# Out:
# 604

# %%
df_new.rename(columns={"video_id": "ID"}, inplace=True)
df_new
# Out:
#               ID
# 0    8irga_AqRdw
# 1    mijGutvsa_U
# 3    NHFt7QTyUfs
# 4    ITjV9Oc5ZZM
# 6    j03_Z28LL0w
# ..           ...
# 794  7Xaau4l9xH0
# 795  JdqxRvZTEfM
# 796  77A1ye1HxqY
# 797  ZOm7vJVpKKU
# 800  v8TpYzl3MIw
#
# [604 rows x 1 columns]

# %%
for i in range(new_size):
  try:
    video = new_videoid.iloc[i]
    name = video +'.csv'
    dt = pd.read_csv(name)
    processed_word = list()
    for op in dt.text:
      new_text = list()
      #words_text = token_space.tokenize(op.translate (str.maketrans ('', '', string.punctuation)))
      words_text = token_space.tokenize(unidecode(op).lower())
      for words in words_text:
        if words not in non_words:
          new_text.append(words)
      #singles = [stemmer.stem(plural) for plural in new_text]
      doc = nlp(str([palavra for palavra in new_text]))
      singles= [token.lemma_ for token in doc]
      processed_word.append(' '.join(singles))


    dt["treatment_1"] = processed_word
    dt.to_csv(name, index=False)
  except:
    print('erro')
    i+=1
# Out:
# erro
# erro
# erro
# erro

# %%
dt
# Out:
#                                          text  \
# 0    ola voce que nos acompanha aqui no canal
# 1                da netshow no youtube eu sou
# 2        meteorologia sisters primeiro aquele
# 3    convite te inscreve aqui no canal aciona
# 4      as notificacoes nao deixe de conversar
# ..                                        ...
# 191    a eventos como esse e que acompanhando
# 192       as redes sociais metrologia a gente
# 193   volta aqui com mais informacao com mais
# 194    conteudo e com mais atualizacoes dessa
# 195        projecao para todos voces ate mais
#
#                                            treatment_1
# 0    [ ' ola ' , ' voce ' , ' acompanhar ' , ' aqui...
# 1                        [ ' netshow ' , ' youtube ' _
# 2     [ ' meteorologia ' , ' sister ' , ' primeiro ' _
# 3    [ ' convite ' , ' inscrever ' , ' aqui ' , ' c...
# 4    [ ' Notificacoes ' , ' nao ' , ' deixar ' , ' ...
# ..                                                 ...
# 191                    [ ' evento ' , ' acompanhar ' _
# 192  [ ' rede ' , ' social ' , ' metrologia ' , ' g...
# 193          [ ' volta ' , ' aqui ' , ' informacao ' _
# 194  [ ' conteudo ' , ' atualizacoes ' , ' de esse ' _
# 195   [ ' projecao ' , ' todo ' , ' voce ' , ' ate ' _
#
# [196 rows x 2 columns]

# %%
sid = si()
for i in range(new_size):
  try:
    video = new_videoid.iloc[i]
    name = video +'.csv'
    dt = pd.read_csv(name)
    score_word = list()
    sentance = dt.loc[:,"treatment_1"]
    t = sentance.size
    for k in range(t):
      word = sentance.iloc[k]
      score = sid.polarity_scores(str(word))
      score_word.append(score)

    dt["Score"] = score_word
    dt.to_csv(name, index=False)
  except:
    i+=1

# %%
dt
# Out:
#                                          text  \
# 0    ola voce que nos acompanha aqui no canal
# 1                da netshow no youtube eu sou
# 2        meteorologia sisters primeiro aquele
# 3    convite te inscreve aqui no canal aciona
# 4      as notificacoes nao deixe de conversar
# ..                                        ...
# 191    a eventos como esse e que acompanhando
# 192       as redes sociais metrologia a gente
# 193   volta aqui com mais informacao com mais
# 194    conteudo e com mais atualizacoes dessa
# 195        projecao para todos voces ate mais
#
#                                            treatment_1  \
# 0    [ ' ola ' , ' voce ' , ' acompanhar ' , ' aqui...
# 1                        [ ' netshow ' , ' youtube ' _
# 2     [ ' meteorologia ' , ' sister ' , ' primeiro ' _
# 3    [ ' convite ' , ' inscrever ' , ' aqui ' , ' c...
# 4    [ ' Notificacoes ' , ' nao ' , ' deixar ' , ' ...
# ..                                                 ...
# 191                    [ ' evento ' , ' acompanhar ' _
# 192  [ ' rede ' , ' social ' , ' metrologia ' , ' g...
# 193          [ ' volta ' , ' aqui ' , ' informacao ' _
# 194  [ ' conteudo ' , ' atualizacoes ' , ' de esse ' _
# 195   [ ' projecao ' , ' todo ' , ' voce ' , ' ate ' _
#
#                                                  Score
# 0    {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'comp...
# 1    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3    {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'comp...
# 4    {'neg': 0.423, 'neu': 0.577, 'pos': 0.0, 'comp...
# ..                                                 ...
# 191  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 192  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 193  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 194  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 195  {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'comp...
#
# [196 rows x 3 columns]

# %%
'''for i in range(new_size):
  try:
    video = new_videoid.iloc[i]
    name = video +'.csv'
    dt = pd.read_csv(name)
    score_word_untreated = list()
    sentance = dt.loc[:,"text"]
    t = sentance.size
    for k in range(t):
      word = sentance.iloc[k]
      score = sid.polarity_scores(str(word))
      score_word_untreated.append(score)

    dt["Score_Untreated"] = score_word_untreated
    dt.to_csv(name, index=False)
  except:
    i+=1'''
# Out:
# 'for i in range(new_size):\n  try:\n    video = new_videoid.iloc[i]\n    name = video +\'.csv\'\n    dt = pd.read_csv(name)\n    score_word_untreated = list()\n    sentance = dt.loc[:,"text"]\n    t = sentance.size\n    for k in range(t):\n      word = sentance.iloc[k]\n      score = sid.polarity_scores(str(word))\n      score_word_untreated.append(score)\n\n    dt["Score_Untreated"] = score_word_untreated\n    dt.to_csv(name, index=False)\n  except:\n    i+=1'

# %%
import ast

# %%
score_list_pos = []
score_list_neg = []
score_list_neutro = []
score_list_compound = []
count=0
for i in range(new_size):
  total_pos = 0
  total_neu = 0
  total_neg = 0
  total_compound = 0

  count=0
  try:
    video = new_videoid.iloc[i]
    name = video +'.csv'
    dt = pd.read_csv(name)
    s = dt['Score']
    for k in dt.Score:
      lista = ast.literal_eval(k)
      total_pos += np.abs(lista['pos'])
      total_neu += np.abs(lista['neu'])
      total_neg += np.abs(lista['neg'])
      total_compound += np.abs(lista['compound'])
      count=count+1
    score_list_neutro.append(total_neu/count)
    score_list_pos.append(total_pos/count)
    score_list_neg.append(total_neg/count)
    score_list_compound.append(total_compound/count)

  except:
    score_list_neutro.append(0)
    score_list_pos.append(0)
    score_list_neg.append(0)
    score_list_compound.append(0)

    i+= 1

# %%
df_new['Neutral Score'] = score_list_neutro
df_new['Positive Score'] = score_list_pos
df_new['Negative Score'] = score_list_neg
df_new['Compund Score'] = score_list_compound

# %%
df_new
# Out:
#               ID  Neutral Score  Positive Score  Negative Score  Compund Score
# 0    8irga_AqRdw       0.742623        0.147275        0.104672       0.175672
# 1    mijGutvsa_U       0.796630        0.143330        0.060020       0.179107
# 3    NHFt7QTyUfs       0.776350        0.148319        0.070934       0.159725
# 4    ITjV9Oc5ZZM       0.672665        0.227191        0.100127       0.214917
# 6    j03_Z28LL0w       0.742159        0.177645        0.079205       0.178102
# ..           ...            ...             ...             ...            ...
# 794  7Xaau4l9xH0       0.832582        0.086923        0.080484       0.114698
# 795  JdqxRvZTEfM       0.758151        0.146909        0.094936       0.220152
# 796  77A1ye1HxqY       0.810557        0.076426        0.113033       0.124962
# 797  ZOm7vJVpKKU       0.779344        0.130820        0.089833       0.157354
# 800  v8TpYzl3MIw       0.830066        0.078893        0.091031       0.117947
#
# [604 rows x 5 columns]

# %%
'''#score_list = []
#score_list_pos = []
#score_list_neg = []
score_list_com = []
score_list_com_test = []
#score_un_list = []
#score_un_list_pos = []
#score_un_list_neg = []
#score_un_list_com = []
for i in range(new_size):
  try:
    total = 0
    total_pos = 0
    total_neu = 0
    total_neg = 0
    test_total = 0
    video = new_videoid.iloc[i]
    name = video +'.csv'
    dt = pd.read_csv(name)
    s = dt['Score']
    #s_un = dt['Score_Untreated']
    for k in dt.Score:
      lista = ast.literal_eval(k)
      square_score_neg = lista['neg']*lista['neg']
      squere_score_pos = lista['pos']*lista['pos']
      test = squere_score_pos+square_score_neg
      test_total += test
      total += lista['compound']
      #total_pos += lista['pos']
      #total_neu += lista['neu']
      #total_neg += lista['neg']
    #score_list.append(total_neu)
    #score_list_pos.append(total_pos)
    #score_list_neg.append(total_neg)
    score_list_com.append(total)
    score_list_com_test.append(test_total)
    #total = 0
    #total_pos = 0
    #total_neu = 0
    #total_neg = 0
    #for i in dt.Score_Untreated:
     # lista = ast.literal_eval(i)
      #total += lista['compound']
      #total_pos += lista['pos']
      #total_neu += lista['neu']
      #total_neg += lista['neg']
    #score_un_list.append(total_neu)
    #score_un_list_pos.append(total_pos)
    #score_un_list_neg.append(total_neg)
    #score_un_list_com.append(total)
  except:
    i+= 1'''
# Out:
# "#score_list = []\n#score_list_pos = []\n#score_list_neg = []\nscore_list_com = []\nscore_list_com_test = []\n#score_un_list = []\n#score_un_list_pos = []\n#score_un_list_neg = []\n#score_un_list_com = []\nfor i in range(new_size):\n  try:\n    total = 0\n    total_pos = 0\n    total_neu = 0\n    total_neg = 0\n    test_total = 0\n    video = new_videoid.iloc[i]\n    name = video +'.csv'\n    dt = pd.read_csv(name)\n    s = dt['Score']\n    #s_un = dt['Score_Untreated']\n    for k in dt.Score:\n      lista = ast.literal_eval(k)\n      square_score_neg = lista['neg']*lista['neg']\n      squere_score_pos = lista['pos']*lista['pos']\n      test = squere_score_pos+square_score_neg\n      test_total += test\n      total += lista['compound']\n      #total_pos += lista['pos']\n      #total_neu += lista['neu']\n      #total_neg += lista['neg']\n    #score_list.append(total_neu)\n    #score_list_pos.append(total_pos)\n    #score_list_neg.append(total_neg)\n    score_list_com.append(total)\n    score_list_com_test.append(test_total)\n    #total = 0\n    #total_pos = 0\n    #total_neu = 0\n    #total_neg = 0\n    #for i in dt.Score_Untreated:\n     # lista = ast.literal_eval(i)\n      #total += lista['compound']\n      #total_pos += lista['pos']\n      #total_neu += lista['neu']\n      #total_neg += lista['neg']\n    #score_un_list.append(total_neu)\n    #score_un_list_pos.append(total_pos)\n    #score_un_list_neg.append(total_neg)\n    #score_un_list_com.append(total)\n  except:\n    i+= 1"

# %%
import ast

# %%
#stuff = ast.literal_eval(s[1])

# %%
#stuff['compound']

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
#API_KEY = "AIzaSyBJVIt1S7y_-5GeqH09u6l8Bm64mLLJSvo"
API_KEY = "AIzaSyA5ftvLLbR1E74ugnJrRGtfp7N7ktxFu0c"

youtube = build('youtube', 'v3', developerKey=API_KEY)

# %%
#df_new['Neutral Score'] = score_list
#df_new['Positive Score'] = score_list_pos
#df_new['Negative Score'] = score_list_neg
#df_new['Total Score Test'] = score_list_com_test
#df_new['Total Score'] = score_list_com
#df_new['Neutral Score Untreated'] = score_un_list
#df_new['Positive Score Untreated'] = score_un_list_pos
#df_new['Negative Score Untreated'] = score_un_list_neg
#df_new['Total Score Untreated'] = score_un_list_com

# %%
df_new
# Out:
#               ID  Neutral Score  Positive Score  Negative Score  Compund Score
# 0    8irga_AqRdw       0.742623        0.147275        0.104672       0.175672
# 1    mijGutvsa_U       0.796630        0.143330        0.060020       0.179107
# 3    NHFt7QTyUfs       0.776350        0.148319        0.070934       0.159725
# 4    ITjV9Oc5ZZM       0.672665        0.227191        0.100127       0.214917
# 6    j03_Z28LL0w       0.742159        0.177645        0.079205       0.178102
# ..           ...            ...             ...             ...            ...
# 794  7Xaau4l9xH0       0.832582        0.086923        0.080484       0.114698
# 795  JdqxRvZTEfM       0.758151        0.146909        0.094936       0.220152
# 796  77A1ye1HxqY       0.810557        0.076426        0.113033       0.124962
# 797  ZOm7vJVpKKU       0.779344        0.130820        0.089833       0.157354
# 800  v8TpYzl3MIw       0.830066        0.078893        0.091031       0.117947
#
# [604 rows x 5 columns]

# %%
for i,row in df_new.iterrows():
  try:
    video_id = row['ID']
    video_request = youtube.videos().list(
          part='snippet,statistics',
          id=video_id
    )

    video_response = video_request.execute()
    likes = video_response['items'][0]['statistics']['likeCount']
    views = video_response['items'][0]['statistics']['viewCount']

    df_new.loc[i, 'Likes'] = int(likes)
    df_new.loc[i, 'Views'] = int(views)
  except:
    df_new.loc[i, 'Likes'] = 0
    df_new.loc[i, 'Views'] = 0
    i+= 1

# %%
proportion=df_new['Likes']*100/df_new['Views']
df_new['Like/Views'] = proportion

# %%
df_new['Like/Views']=df_new['Like/Views'].fillna(0)
df_new['Like/Views']
# Out:
# 0      14.388809
# 1      10.578800
# 3       7.098168
# 4      11.354842
# 6      11.318486
#          ...
# 794    14.506469
# 795     8.781749
# 796     6.867885
# 797     6.392538
# 800     6.334268
# Name: Like/Views, Length: 604, dtype: float64

# %%
disabled_comments_indices = []

for i,row in df_new.iterrows():

  video_id = row['ID']
  try:
      # Fetch the comments
      comments_request = youtube.commentThreads().list(
        part='snippet',
        videoId=video_id,
        maxResults=3000,  # Limit to 3000 comments
        textFormat='plainText'
        )
      comments_response = comments_request.execute()

        # Extract the comments
      comments = [item['snippet']['topLevelComment']['snippet']['textDisplay']
                    for item in comments_response['items']]

        # Create a DataFrame for the comments
      comments_df = pd.DataFrame(comments, columns=['Comment'])

        # Save the comments to a CSV file
      comments_df.to_csv(f'{video_id}_comments.csv', index=False)

  except HttpError as e:
      if 'commentsDisabled' in str(e):
          # If comments are disabled for the video, add its index to the list
          disabled_comments_indices.append(i)

# Remove videos with disabled comments from the original DataFrame
df_new.drop(disabled_comments_indices, inplace=True)

# Save the updated DataFrame to a new CSV file
df_new.to_csv('updated_file.csv', index=False)
# Out:
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"

# %%
df_new
# Out:
#               ID  Neutral Score  Positive Score  Negative Score  \
# 0    8irga_AqRdw       0.742623        0.147275        0.104672
# 1    mijGutvsa_U       0.796630        0.143330        0.060020
# 3    NHFt7QTyUfs       0.776350        0.148319        0.070934
# 4    ITjV9Oc5ZZM       0.672665        0.227191        0.100127
# 6    j03_Z28LL0w       0.742159        0.177645        0.079205
# ..           ...            ...             ...             ...
# 794  7Xaau4l9xH0       0.832582        0.086923        0.080484
# 795  JdqxRvZTEfM       0.758151        0.146909        0.094936
# 796  77A1ye1HxqY       0.810557        0.076426        0.113033
# 797  ZOm7vJVpKKU       0.779344        0.130820        0.089833
# 800  v8TpYzl3MIw       0.830066        0.078893        0.091031
#
#      Compund Score    Likes     Views  Like/Views
# 0         0.175672   9052.0   62910.0   14.388809
# 1         0.179107  12518.0  118331.0   10.578800
# 3         0.159725  59824.0  842809.0    7.098168
# 4         0.214917  16580.0  146017.0   11.354842
# 6         0.178102   4894.0   43239.0   11.318486
# ..             ...      ...       ...         ...
# 794       0.114698  42291.0  291532.0   14.506469
# 795       0.220152  86579.0  985897.0    8.781749
# 796       0.124962  32236.0  469373.0    6.867885
# 797       0.157354  58947.0  922122.0    6.392538
# 800       0.117947   7639.0  120598.0    6.334268
#
# [575 rows x 8 columns]

# %%
for i in range(len(df_new['ID'])):
  try:
    video = df_new['ID'].iloc[i]
    name = video +'_comments.csv'
    dt = pd.read_csv(name)
    processed_word = list()
    for op in dt.Comment:
      new_text = list()
      words_text = token_space.tokenize(unidecode(op).lower())
      for words in words_text:
        if words not in non_words:
          new_text.append(words)
      #singles = [stemmer.stem(plural) for plural in new_text]
      doc = nlp(str([palavra for palavra in new_text]))
      singles= [token.lemma_ for token in doc]
      processed_word.append(' '.join(singles))

    dt["treatment_1"] = processed_word
    dt.to_csv(name, index=False)
  except:
    i+=1

# %%
for i in range(len(df_new['ID'])):
  try:
    video = df_new['ID'].iloc[i]
    name = video +'_comments.csv'
    dt = pd.read_csv(name)
    score_word = list()
    sentance = dt.loc[:,"treatment_1"]
    t = sentance.size
    for k in range(t):
      word = sentance.iloc[k]
      score = sid.polarity_scores(str(word))
      score_word.append(score)

    dt["Score"] = score_word
    dt.to_csv(name, index=False)
  except:
    i+=1

# %%
total_neg_com = 0
total_pos_com = 0
total_neu_com = 0
total_compound_com = 0

score_list_pos_com = []
score_list_neg_com = []
score_list_neutro_com = []
score_list_compound_com = []
count=0
for i in range(len(df_new['ID'])):
  total_neg_com = 0
  total_pos_com = 0
  total_neu_com = 0
  total_compound_com = 0
  count=0
  try:
    video = df_new['ID'].iloc[i]
    name = video +'_comments.csv'
    dt = pd.read_csv(name)
    s = dt['Score']
    for k in dt.Score:
      lista = ast.literal_eval(k)
      total_neg_com += np.abs(lista['neg'])
      total_pos_com += np.abs(lista['pos'])
      total_neu_com += np.abs(lista['neu'])
      total_compound_com += np.abs(lista['compound'])
      count=count+1


    score_list_neutro_com.append(total_neu_com/count)
    score_list_pos_com.append(total_pos_com/count)
    score_list_neg_com.append(total_neg_com/count)
    score_list_compound_com.append(total_compound_com/count)

  except:
    i+= 1
    score_list_neutro_com.append(total_neu_com)
    score_list_pos_com.append(total_pos_com)
    score_list_neg_com.append(total_neg_com)
    score_list_compound_com.append(total_compound_com)

# %%
df_new['Comment Score Neg'] = score_list_neg_com
df_new['Comment Score Pos'] = score_list_pos_com
df_new['Comment Score Neu'] = score_list_neutro_com
df_new['Comment Score Compund'] = score_list_compound_com

# %%
df_new
df_new.to_csv('df_new_scores_pt.csv', index=False)

# %%
from google.colab import files

# Fazer o download do arquivo
files.download('df_new_scores_pt.csv')

# %%
files.download('updated_file.csv')
